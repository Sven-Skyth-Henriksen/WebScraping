# %%
#do the imports
import numpy as np
import pandas as pd

print('setup complete')
# Out:
# setup complete

# %%
df = pd.read_csv('supplements.csv')

# %%
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='flavor')
df.dropna()
# Out:
#                                name  rating  \
# 0      Crunchy Protein Bar (12x64g)     5.0
# 1      Crunchy Protein Bar (12x64g)     5.0
# 2              Whey Protein (2000g)     3.9
# 3              Whey Protein (2000g)     3.9
# 6              Whey Protein (1000g)     3.9
# ...                             ...     ...
# 2101  Protein Delite Pulver (1000g)     5.0
# 2304          Nitro Pump 3.0 (400g)     3.0
# 2305          Nitro Pump 3.0 (400g)     3.0
# 2310             Profi Mass (2500g)     1.0
# 2311             Profi Mass (2500g)     1.0
#
#                                             ingredients    price
# 0     Schokoladen Brownie: 31% Milchschokoladenüberz...  16,16 €
# 1     Schokoladen Brownie: 31% Milchschokoladenüberz...  16,16 €
# 2     Vanille: Cross-flow ultra filtriertes Molkenpr...  25,00 €
# 3     Vanille: Cross-flow ultra filtriertes Molkenpr...  25,00 €
# 6     Erdbeer: Cross-flow ultra filtriertes Molkenpr...  25,00 €
# ...                                                 ...      ...
# 2101  Ananas-Vanille: ultrafiltriertes Molkenprotein...  23,99 €
# 2304  Cranberry: L-Citrullin-Malat (16%), wasserfrei...  35,99 €
# 2305  Cranberry: L-Citrullin-Malat (16%), wasserfrei...  35,99 €
# 2310  56% Eiweißerzeugnisse (Molkeneiweißkonzentrat,...  47,99 €
# 2311  56% Eiweißerzeugnisse (Molkeneiweißkonzentrat,...  47,99 €
#
# [391 rows x 4 columns]
